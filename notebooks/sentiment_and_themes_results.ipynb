# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("../data/bank_reviews_with_sentiment_and_themes.csv")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Display the  rows and colomn as a table
df.head(1328)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     review  \
# ...

# %%
# Number of reviews 
import pandas as pd

# Count reviews per bank
review_counts = df['bank'].value_counts()

# Plot bar chart
plt.figure(figsize=(8, 5))
review_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Number of Reviews per Fintech App')
plt.xlabel('Bank')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import sys
import os

# Add the path to the src folder
sys.path.append(os.path.abspath("../src/"))

# Import the function
from bank_sentiment import plot_sentiment_by_bank

# Load the data
import pandas as pd
df = pd.read_csv("../data/bank_reviews_with_sentiment_and_themes.csv")

# Call the plot function
plot_sentiment_by_bank(df)

# %%
import sys
import os

# Add the src directory to sys.path
sys.path.append(os.path.abspath("../src/"))

# Now import the function
from chart1 import plot_sentiment_distribution

# Load your DataFrame
import pandas as pd
df = pd.read_csv("../data/bank_reviews_with_sentiment_and_themes.csv")

# Call the function
plot_sentiment_distribution(df)

# %%
import sys
import os

# Add the src directory to sys.path
sys.path.append(os.path.abspath("../src/"))

# Now import the function
from chart3 import plot_sentiment_by_bank

# Load your DataFrame
import pandas as pd
df = pd.read_csv("../data/bank_reviews_with_sentiment_and_themes.csv")

# Call the function
plot_sentiment_by_bank(df)

# %%
import sys
import os

# Add path to src directory
sys.path.append(os.path.abspath("../src/"))

# Import the function
from heatmap import plot_sentiment_theme_heatmap

# Load your dataset
import pandas as pd
df = pd.read_csv("../data/bank_reviews_with_sentiment_and_themes.csv")

# Call the function
plot_sentiment_theme_heatmap(df)
